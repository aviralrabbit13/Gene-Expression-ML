# %% [markdown]
# <a href="https://colab.research.google.com/github/aviralrabbit13/Gene-Expression-ML/blob/main/Gene_exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as num
import pandas as an
import os
import matplotlib.pyplot as mat

# %%
os.listdir("drive/MyDrive/Gene")
# Out:
# ['data.csv', 'labels.csv', 'split60_40']

# %%
data = an.read_csv('drive/MyDrive/Gene/data.csv',delimiter = ',')
labels = an.read_csv('drive/MyDrive/Gene/labels.csv',delimiter = ',')

# %%
data.describe()
# Out:
#            gene_0      gene_1      gene_2  ...  gene_20528  gene_20529  gene_20530
# count  801.000000  801.000000  801.000000  ...  801.000000  801.000000  801.000000
# mean     0.026642    3.010909    3.095350  ...    9.590726    5.528177    0.095411
# std      0.136850    1.200828    1.065601  ...    0.563849    2.073859    0.364529
# min      0.000000    0.000000    0.000000  ...    7.864533    0.593975    0.000000
# 25%      0.000000    2.299039    2.390365  ...    9.244219    4.092385    0.000000
# 50%      0.000000    3.143687    3.127006  ...    9.566511    5.218618    0.000000
# 75%      0.000000    3.883484    3.802534  ...    9.917888    6.876382    0.000000
# max      1.482332    6.237034    6.063484  ...   12.813320   11.205836    5.254133
#
# [8 rows x 20531 columns]

# %%
labels.describe()
# Out:
#         Unnamed: 0 Class
# count          801   801
# unique         801     5
# top     sample_545  BRCA
# freq             1   300

# %%
data.head()
# Out:
#   Unnamed: 0  gene_0    gene_1  ...  gene_20528  gene_20529  gene_20530
# 0   sample_0     0.0  2.017209  ...    8.921326    5.286759         0.0
# 1   sample_1     0.0  0.592732  ...    9.397854    2.094168         0.0
# 2   sample_2     0.0  3.511759  ...   10.090470    1.683023         0.0
# 3   sample_3     0.0  3.663618  ...    9.684365    3.292001         0.0
# 4   sample_4     0.0  2.655741  ...    9.461191    5.110372         0.0
#
# [5 rows x 20532 columns]

# %%
labels.head()
# Out:
#   Unnamed: 0 Class
# 0   sample_0  PRAD
# 1   sample_1  LUAD
# 2   sample_2  PRAD
# 3   sample_3  PRAD
# 4   sample_4  BRCA

# %%
data.isnull()
# Out:
#      Unnamed: 0  gene_0  gene_1  ...  gene_20528  gene_20529  gene_20530
# 0         False   False   False  ...       False       False       False
# 1         False   False   False  ...       False       False       False
# 2         False   False   False  ...       False       False       False
# 3         False   False   False  ...       False       False       False
# 4         False   False   False  ...       False       False       False
# ..          ...     ...     ...  ...         ...         ...         ...
# 796       False   False   False  ...       False       False       False
# 797       False   False   False  ...       False       False       False
# 798       False   False   False  ...       False       False       False
# 799       False   False   False  ...       False       False       False
# 800       False   False   False  ...       False       False       False
#
# [801 rows x 20532 columns]

# %%
data['Unnamed: 0']
# Out:
# 0        sample_0
# 1        sample_1
# 2        sample_2
# 3        sample_3
# 4        sample_4
#           ...
# 796    sample_796
# 797    sample_797
# 798    sample_798
# 799    sample_799
# 800    sample_800
# Name: Unnamed: 0, Length: 801, dtype: object

# %%
labels['Unnamed: 0']
# Out:
# 0        sample_0
# 1        sample_1
# 2        sample_2
# 3        sample_3
# 4        sample_4
#           ...
# 796    sample_796
# 797    sample_797
# 798    sample_798
# 799    sample_799
# 800    sample_800
# Name: Unnamed: 0, Length: 801, dtype: object

# %%
labels['Class']
# Out:
# 0      PRAD
# 1      LUAD
# 2      PRAD
# 3      PRAD
# 4      BRCA
#        ...
# 796    BRCA
# 797    LUAD
# 798    COAD
# 799    PRAD
# 800    PRAD
# Name: Class, Length: 801, dtype: object

# %%
df = an.DataFrame(data)

# %%
df.join(labels.set_index('Unnamed: 0'), on = 'Unnamed: 0')
# Out:
#      Unnamed: 0  gene_0    gene_1  ...  gene_20529  gene_20530  Class
# 0      sample_0     0.0  2.017209  ...    5.286759    0.000000   PRAD
# 1      sample_1     0.0  0.592732  ...    2.094168    0.000000   LUAD
# 2      sample_2     0.0  3.511759  ...    1.683023    0.000000   PRAD
# 3      sample_3     0.0  3.663618  ...    3.292001    0.000000   PRAD
# 4      sample_4     0.0  2.655741  ...    5.110372    0.000000   BRCA
# ..          ...     ...       ...  ...         ...         ...    ...
# 796  sample_796     0.0  1.865642  ...    8.819269    0.000000   BRCA
# 797  sample_797     0.0  3.942955  ...    9.659081    0.000000   LUAD
# 798  sample_798     0.0  3.249582  ...    4.677458    0.586693   COAD
# 799  sample_799     0.0  2.590339  ...    5.718751    0.000000   PRAD
# 800  sample_800     0.0  2.325242  ...    4.550716    0.000000   PRAD
#
# [801 rows x 20533 columns]

# %%
df1 = an.merge(df, labels, left_on='Unnamed: 0', right_on ='Unnamed: 0', how='left').drop('Unnamed: 0',axis=1)

# %%
df1.head()
# Out:
#    gene_0    gene_1    gene_2  ...  gene_20529  gene_20530  Class
# 0     0.0  2.017209  3.265527  ...    5.286759         0.0   PRAD
# 1     0.0  0.592732  1.588421  ...    2.094168         0.0   LUAD
# 2     0.0  3.511759  4.327199  ...    1.683023         0.0   PRAD
# 3     0.0  3.663618  4.507649  ...    3.292001         0.0   PRAD
# 4     0.0  2.655741  2.821547  ...    5.110372         0.0   BRCA
#
# [5 rows x 20532 columns]

# %%
#splitting the data for test and train

from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size = 0.4, random_state=42, shuffle = True)

# %%
#os.mkdir('drive/MyDrive/Gene/split60_40')
os.listdir('drive/MyDrive/Gene')
# Out:
# ['data.csv', 'labels.csv', 'split60_40']

# %%
from pathlib import Path 
train_path = os.path.join('drive/MyDrive/Gene/split60_40','train.csv')
test_path = os.path.join('drive/MyDrive/Gene/split60_40','test.csv')

# %%
train.to_csv(train_path, sep=',', index= False)
test.to_csv(test_path, sep=',', index= False)

# %%
test, valid = train_test_split(test, test_size = 0.5,random_state=42,shuffle = True)

# %%
test_path = os.path.join('drive/MyDrive/Gene/split60_40','test.csv')
valid_path = os.path.join('drive/MyDrive/Gene/split60_40','valid.csv')

# %%
test.to_csv(train_path, sep=',', index= False)
valid.to_csv(valid_path, sep=',', index= False)

# %%
print("number of example in Training set = "+ str(train['Class'].count()));
print("number of example in test set = "+ str(test['Class'].count()));
print("number of example in valid set = "+ str(test['Class'].count()));
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-197-e4eba105f5eb> in <module>()
# ...

# %%
train_labels = train['Class']
del train['Class']
train_features = train
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-198-0a91f5e4e53a> in <module>()
# ...

# %%
test_labels = test['Class']
del test['Class']
test_features = test

# %%
valid_labels = valid['Class']
del valid['Class']
valid_features = valid

# %%
valid_labels;valid_features
test_labels;test_features

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.backend import one_hot

# %%
len(train_features.columns)

# %%
labels['Class'].unique()

# %%
labels = labels['Class'].replace(to_replace='PRAD', value =0, regex=True)
labels = labels['Class'].replace(to_replace='LUAD', value =1,regex=True)
labels = labels['Class'].replace(to_replace='BRCA', value =2,regex=True)
labels = labels['Class'].replace(to_replace='KIRC', value =3,regex=True)
labels = labels['Class'].replace(to_replace='COAD', value =4,regex=True)

# %%
llabels['Class'].replace(to_replace='LUAD', value =1,regex=True)
labels['Class'].replace(to_replace='BRCA', value =2,regex=True)
labels['Class'].replace(to_replace='KIRC', value =3,regex=True)
labels['Class'].replace(to_replace='COAD', value =4,regex=True)

# %% [markdown]
# ### **For 5 classes, we'll have 5 neurons in the output layers**

# %%
train_labels = an.DataFrame(train_labels).to_numpy()
test_labels = an.DataFrame(test_labels).to_numpy()
valid_labels = an.DataFrame(valid_labels).to_numpy()

train_features = an.DataFrame(train_features).to_numpy()
test_features = an.DataFrame(test_features).to_numpy()
valid_features = an.DataFrame(valid_features).to_numpy()

# %%
train_labels = tf.keras.backend.one_hot(train_labels,5)
